# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **1. Display Top 10 Rows of the Dataset**

# %%
#read the dataset
data=pd.read_csv("/content/Ecommerce Purchases")
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# **2.Check Last 10 Rows of the Dataset**

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# **3.Check Datatype of Each Column**

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# **4.Check Null Values in Dataset.**

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# **5.How many columns are there in our Dataset?**

# %%
x,y=data.shape
print("Number of Columns are:",y)
# Out:
# Number of Columns are: 14

# %% [markdown]
# **6.Highest and Lowest Purchase Prices.**

# %%
#Highest Price
high=data['Purchase Price'].max()
print("Highest Purchase Price:-",high)

#Lowest Price
Low=data['Purchase Price'].min()
print("Lowest Purchase Price:-",Low)
# Out:
# Highest Purchase Price:- 99.99
# Lowest Purchase Price:- 0.0

# %% [markdown]
# **7.Average Purchase Price.**

# %%
#Average purchase Price
avg=data['Purchase Price'].mean()
print("Average Purchase Price:-",avg)
# Out:
# Average Purchase Price:- 50.347302

# %% [markdown]
# **8.How many people have french "fr" as their language?**

# %%
fr=data['Language'][data['Language']=='fr']
fr.value_counts()
# Out:
# fr    1097
# Name: Language, dtype: int64

# %% [markdown]
# **9.Job Title contains Engineer.**

# %%
d=data['Job'][data['Job'].str.contains('engineer',case=False)]
d
# Out:
# 1                         Drilling engineer
# 3                         Drilling engineer
# 50                      Mechanical engineer
# 55      Engineer, broadcasting (operations)
# 60                   Engineer, agricultural
#                        ...
# 9948                    Structural engineer
# 9952                       Engineer, energy
# 9970                    Electrical engineer
# 9977                    Biomedical engineer
# 9996                        Energy engineer
# Name: Job, Length: 984, dtype: object

# %% [markdown]
# **10.Find the Email of the person with the following IP Adress:132.207.160.22**

# %%
data[['Email','IP Address']][data['IP Address']=='132.207.160.22']
# Out:
#                             Email      IP Address
# 2  amymiller@morales-harrison.com  132.207.160.22

# %% [markdown]
# **11.How many People have Mastercard as their Credit Card Provider and made a purchase above 50.**

# %%
d=data[(data['CC Provider']=='Mastercard') & (data['Purchase Price']>50)]
len(d)
# Out:
# 405

# %% [markdown]
# **12.Find the email of the person with the following Credit Card Number: 4664825258997302**

# %%
data[['Email','Credit Card']][data['Credit Card']==4664825258997302]
# Out:
#                   Email       Credit Card
# 9992  bberry@wright.net  4664825258997302

# %% [markdown]
# **13.How many people purchase during the AM and how many people purchase during PM?**

# %%
AM=data[data['AM or PM']=='AM']
PM=data[data['AM or PM']=='PM']
print("Number of people purchase during AM :=",len(AM))
print("Number of people purchase during PM :=",len(PM))
# Out:
# Number of people purchase during AM := 4932
# Number of people purchase during PM := 5068

# %% [markdown]
# **14.How many people have a credit card that expires in 2020?**

# %%
data[data['CC Exp Date']]

# %%
data.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...
